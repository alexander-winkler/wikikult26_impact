# %% [markdown]
# # Anregung
#
# Wie wäre es mit einer Funktion, die eine SRU-Anfrage mit einem query erlaubt und dann neben Autor:innennamen und Buchtitel auch Fotos von Autor:innen GND-ID aus Wikidata zieht und anzeigt?
